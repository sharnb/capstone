# %% [markdown]
# # Show Content Recommender
# > Author: Sharnique Beck
#
# This notebook is where I build the content based recommender system

# %%
# import Libraries
import pandas as pd
import re

from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

from nltk.tokenize import RegexpTokenizer

# %%
data = pd.read_csv('../data/merged_content.csv')
shows = pd.read_csv('../data/k_titles.csv')
data.head()
# Out:
#                   title                                            content
# 0  Thirty But Seventeen  KoreanDrama Drama Romance Comedy Crime&Mystery...
# 1      Fates and Furies  Romance Melodrama KoreanDrama JooSangWook LeeM...
# 2      The Last Empress  KoreanDrama Drama Romance ShinSungRok JangNara...
# 3             Encounter  Romance KoreanDrama ParkBoGum SongHyeKyo JangS...
# 4       My Strange Hero  Romance Melodrama Drama KoreanDrama YooSeungHo...

# %%
shows.head()
# Out:
#                   title                                                url  \
# 0  Thirty But Seventeen  https://www.viki.com/tv/36109c-thirty-but-seve...
# 1      Fates and Furies    https://www.viki.com/tv/36240c-fates-and-furies
# 2      The Last Empress    https://www.viki.com/tv/36241c-the-last-empress
# 3             Encounter           https://www.viki.com/tv/36239c-encounter
# 4       My Strange Hero     https://www.viki.com/tv/36330c-my-strange-hero
#
#   container  rating  # ratings
# 0    36109c    9.58       7368
# 1    36240c    9.14       1401
# 2    36241c    9.45       3858
# 3    36239c    9.59       5436
# 4    36330c    9.56       2239

# %%
# Create tokens at spaces in string only
REGEX = re.compile(r"\s+")
def tokenize(text):
    return [tok.strip() for tok in REGEX.split(text)]

# %%
vect = CountVectorizer(lowercase=False,tokenizer=tokenize, stop_words=['','[]']) 
cont = vect.fit_transform(data['content'])
content = pd.DataFrame(cont.toarray(), columns=vect.get_feature_names())
content.index = data['title']
content.head()
# Out:
#                       "Jimin(AOAs)"  "KimTaehyung(BTSsV)"  \
# title
# Thirty But Seventeen              0                     0
# Fates and Furies                  0                     0
# The Last Empress                  0                     0
# Encounter                         0                     0
# My Strange Hero                   0                     0
#
#                       "KwonMina(AoAsMinA)"  (G)I-DLE  10cm  A-Tom  AOA  \
# title
# Thirty But Seventeen                     0         0     0      0    0
# Fates and Furies                         0         0     0      0    0
# The Last Empress                         0         0     0      0    0
# Encounter                                0         0     0      0    0
# My Strange Hero                          0         0     0      0    0
#
#                       AbigailAlderete  Action&Adventure  AgathaChristie  \
# title
# Thirty But Seventeen                0                 0               0
# Fates and Furies                    0                 0               0
# The Last Empress                    0                 0               0
# Encounter                           0                 0               0
# My Strange Hero                     0                 0               0
#
#                            ...        YunMinSu  YunSangHo  YunSeongSik  Yuna  \
# title                      ...
# Thirty But Seventeen       ...               0          0            0     0
# Fates and Furies           ...               0          0            0     0
# The Last Empress           ...               0          0            0     0
# Encounter                  ...               0          0            0     0
# My Strange Hero            ...               0          0            0     0
#
#                       Yura  ZAZI  gugudan  iKON  kk  nikitaklæstrup
# title
# Thirty But Seventeen     0     0        0     0   0               0
# Fates and Furies         0     0        0     0   0               0
# The Last Empress         0     0        0     0   0               0
# Encounter                0     0        0     0   0               0
# My Strange Hero          0     0        0     0   0               0
#
# [5 rows x 2916 columns]

# %%
recommender = pairwise_distances(content, metric='cosine')
recommender[:5,:5]
# Out:
# array([[0.        , 0.8232233 , 0.82850141, 0.88888889, 0.82850141],
#        [0.8232233 , 0.        , 0.87873219, 0.88214887, 0.81809828],
#        [0.82850141, 0.87873219, 0.        , 0.88566761, 0.82352941],
#        [0.88888889, 0.88214887, 0.88566761, 0.        , 0.88566761],
#        [0.82850141, 0.81809828, 0.82352941, 0.88566761, 0.        ]])

# %%
# Convert matrix into a Dataframe
recommender_df = pd.DataFrame(recommender, index = content.index, columns=content.index)
recommender_df.head()
# Out:
# title                 Thirty But Seventeen  Fates and Furies  \
# title
# Thirty But Seventeen              0.000000          0.823223
# Fates and Furies                  0.823223          0.000000
# The Last Empress                  0.828501          0.878732
# Encounter                         0.888889          0.882149
# My Strange Hero                   0.828501          0.818098
#
# title                 The Last Empress  Encounter  My Strange Hero  \
# title
# Thirty But Seventeen          0.828501   0.888889         0.828501
# Fates and Furies              0.878732   0.882149         0.818098
# The Last Empress              0.000000   0.885668         0.823529
# Encounter                     0.885668   0.000000         0.885668
# My Strange Hero               0.823529   0.885668         0.000000
#
# title                 What’s Wrong With Secretary Kim  Devilish Joy  \
# title
# Thirty But Seventeen                         0.899496      0.833333
# Fates and Furies                             0.893400      0.823223
# The Last Empress                             0.896582      0.742752
# Encounter                                    0.899496      0.833333
# My Strange Hero                              0.896582      0.828501
#
# title                 I Am Not a Robot  Suspicious Partner  \
# title
# Thirty But Seventeen          0.789181            0.777778
# Fates and Furies              0.888197            0.882149
# The Last Empress              0.837302            0.828501
# Encounter                     0.894591            0.833333
# My Strange Hero               0.728837            0.828501
#
# title                 Weightlifting Fairy Kim Bok Joo         ...           \
# title                                                         ...
# Thirty But Seventeen                         0.828501         ...
# Fates and Furies                             0.878732         ...
# The Last Empress                             0.823529         ...
# Encounter                                    0.885668         ...
# My Strange Hero                              0.823529         ...
#
# title                 I Came Alone  Assembly  2017 SBS Entertainment Awards  \
# title
# Thirty But Seventeen      0.916667  0.878284                       0.951887
# Fates and Furies          1.000000  0.806351                       1.000000
# The Last Empress          1.000000  0.874755                       1.000000
# Encounter                 1.000000  0.939142                       1.000000
# My Strange Hero           1.000000  0.812133                       0.900985
#
# title                 Ricky Traveling Alone  2016 DMC Festival  \
# title
# Thirty But Seventeen                    1.0                1.0
# Fates and Furies                        1.0                1.0
# The Last Empress                        1.0                1.0
# Encounter                               1.0                1.0
# My Strange Hero                         1.0                1.0
#
# title                 All Broadcasts of the World  \
# title
# Thirty But Seventeen                     0.937006
# Fates and Furies                         1.000000
# The Last Empress                         1.000000
# Encounter                                1.000000
# My Strange Hero                          1.000000
#
# title                 2017 MBC Entertainment Awards  Join Us Korea  \
# title
# Thirty But Seventeen                       0.951887            1.0
# Fates and Furies                           1.000000            1.0
# The Last Empress                           1.000000            1.0
# Encounter                                  1.000000            1.0
# My Strange Hero                            1.000000            1.0
#
# title                 LC9's Life of Research  The Seg 101 Express
# title
# Thirty But Seventeen                     1.0                  1.0
# Fates and Furies                         1.0                  1.0
# The Last Empress                         1.0                  1.0
# Encounter                                1.0                  1.0
# My Strange Hero                          1.0                  1.0
#
# [5 rows x 624 columns]

# %%
recommender_df['Healer'].sort_values()[1:11]
# Out:
# title
# The Great Doctor        0.636197
# Queen for Seven Days    0.655876
# The K2                  0.677251
# Old Goodbye             0.693814
# EXIT                    0.698489
# Again, My Love          0.711325
# Star’s Lover            0.711325
# Traces of the Hand      0.716527
# Hotelier                0.716527
# Tamra the Island        0.720492
# Name: Healer, dtype: float64

# %%
# system for titles with the given word and display top 10 matches
search = "LeeMinHo"
for t in shows[shows['title'].str.contains(search)]['title'].values:
    print(t)
    print('Average Rating', data[data['title']==t]['rating'].mean())
    print('Number of Ratings', data[data['title']==t]['rating'].shape[0])
    print(' ')
    print('Recommendations:')
    print(recommender_df[t].sort_values()[1:11])
    print(' ')
    print('***********************************************************')

# %%
cosine_sim = cosine_similarity(content, content)
cosine_sim[:5,:5]
# Out:
# array([[1.        , 0.1767767 , 0.17149859, 0.11111111, 0.17149859],
#        [0.1767767 , 1.        , 0.12126781, 0.11785113, 0.18190172],
#        [0.17149859, 0.12126781, 1.        , 0.11433239, 0.17647059],
#        [0.11111111, 0.11785113, 0.11433239, 1.        , 0.11433239],
#        [0.17149859, 0.18190172, 0.17647059, 0.11433239, 1.        ]])

# %%
indices = pd.Series(content.index)
indices[:5]
# Out:
# 0    Thirty But Seventeen
# 1        Fates and Furies
# 2        The Last Empress
# 3               Encounter
# 4         My Strange Hero
# Name: title, dtype: object

# %%
# function that takes in movie title as input and returns the top 10 recommended movies
def recommendations(title, cosine_sim = cosine_sim):
    
    recommended_movies = []
    
    # gettin the index of the movie that matches the title
    idx = indices[indices == title].index[0]

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar movies
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    # populating the list with the titles of the best 10 matching movies
    for i in top_10_indexes:
        recommended_movies.append(list(content.index)[i])
        
    return recommended_movies

# %%
recommendations('Healer')
# Out:
# ['The Great Doctor',
#  'Queen for Seven Days',
#  'The K2',
#  'Old Goodbye',
#  'EXIT',
#  'Star’s Lover',
#  'Again, My Love',
#  'Traces of the Hand',
#  'Hotelier',
#  'Tamra the Island']
