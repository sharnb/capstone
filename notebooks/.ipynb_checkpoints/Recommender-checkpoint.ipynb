# %% [markdown]
# # Show Recommender
# > Author: Sharnique Beck

# %%
# import Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances

# %%
shows = pd.read_csv('./data/k_titles.csv')
data = pd.read_csv('./data/ratings_data.csv')

# %%
# Drop columns that will not be used
shows.drop(columns=['url','container','# ratings'], axis=1,inplace=True)
shows.head()
# Out:
#                   title  rating
# 0  Thirty But Seventeen    9.58
# 1      Fates and Furies    9.14
# 2      The Last Empress    9.45
# 3             Encounter    9.59
# 4       My Strange Hero    9.56

# %%
data.head()
# Out:
#    rating                   title                  user  user_id
# 0      10    Thirty But Seventeen                la_fra    19253
# 1      10                       W                la_fra    19253
# 2      10  Descendants of the Sun                la_fra    19253
# 3      10            Fight My Way                la_fra    19253
# 4      10    Thirty But Seventeen  jyotikababbar999_688   143260

# %%
data.shape
# Out:
# (402426, 4)

# %% [markdown]
# ## Create Pivot table

# %%
# Create pivot table to show user rating for each title
pivot = pd.pivot_table(data, index ='title', columns= 'user_id', values='rating')
pivot.head()
# Out:
# user_id                              0       1       2       3       4       \
# title
# 109 Strange Things                      NaN     NaN     NaN     NaN     NaN
# 12th Annual Soompi Awards               NaN     NaN     NaN     NaN     NaN
# 2 Days and 1 Night                      NaN     NaN     NaN     NaN     NaN
# 2014 Idol Star Athletics Champio...     NaN     NaN     NaN     NaN     NaN
# 2015 Idol Star Athletics Champio...     NaN     NaN     NaN     NaN     NaN
#
# user_id                              5       6       7       8       9       \
# title
# 109 Strange Things                      NaN     NaN     NaN     3.0     NaN
# 12th Annual Soompi Awards               NaN     NaN     NaN     NaN     NaN
# 2 Days and 1 Night                      NaN    10.0     NaN     NaN     NaN
# 2014 Idol Star Athletics Champio...     NaN     NaN     NaN     NaN     NaN
# 2015 Idol Star Athletics Champio...     NaN     NaN     NaN     NaN     NaN
#
# user_id                               ...    183640  183641  183642  183643  \
# title                                 ...
# 109 Strange Things                    ...       NaN     NaN     NaN     NaN
# 12th Annual Soompi Awards             ...       NaN     NaN     NaN     NaN
# 2 Days and 1 Night                    ...       NaN     NaN     NaN     NaN
# 2014 Idol Star Athletics Champio...   ...       NaN     NaN     NaN     NaN
# 2015 Idol Star Athletics Champio...   ...       NaN     NaN     NaN     NaN
#
# user_id                              183644  183645  183646  183647  183648  \
# title
# 109 Strange Things                      NaN     NaN     NaN     NaN     NaN
# 12th Annual Soompi Awards               NaN     NaN     NaN     NaN     NaN
# 2 Days and 1 Night                      NaN     NaN     NaN     NaN     NaN
# 2014 Idol Star Athletics Champio...     NaN     NaN     NaN     NaN     NaN
# 2015 Idol Star Athletics Champio...     NaN     NaN     NaN     NaN     NaN
#
# user_id                              183649
# title
# 109 Strange Things                      NaN
# 12th Annual Soompi Awards               NaN
# 2 Days and 1 Night                      NaN
# 2014 Idol Star Athletics Champio...     NaN
# 2015 Idol Star Athletics Champio...     NaN
#
# [5 rows x 183650 columns]

# %% [markdown]
# ## Create Sparse Matrix

# %%
# The sparse matrix combines the (title, user and their rating of that title)
# create a sparse matrix and fill empty cells with 0
pivot_sparse = sparse.csr_matrix(pivot.fillna(0))

# %% [markdown]
# ## Calculate Cosine Similarity

# %%
# Compare movies to each other in a square matrix
# Calculate the cosine similarity using pairwise distances
recommender = pairwise_distances(pivot_sparse, metric='cosine')

# %%
# Looks at the first 5 movies compared to each other
recommender[:5,:5]
# Out:
# array([[0.        , 1.        , 0.99183537, 1.        , 1.        ],
#        [1.        , 0.        , 1.        , 1.        , 1.        ],
#        [0.99183537, 1.        , 0.        , 1.        , 1.        ],
#        [1.        , 1.        , 1.        , 0.        , 1.        ],
#        [1.        , 1.        , 1.        , 1.        , 0.        ]])

# %%
# Convert matrix into a Dataframe
recommender_df = pd.DataFrame(recommender, index = pivot.index, columns=pivot.index)
recommender_df.head()
# Out:
# title                                109 Strange Things  \
# title
# 109 Strange Things                             0.000000
# 12th Annual Soompi Awards                      1.000000
# 2 Days and 1 Night                             0.991835
# 2014 Idol Star Athletics Champio...            1.000000
# 2015 Idol Star Athletics Champio...            1.000000
#
# title                                12th Annual Soompi Awards  \
# title
# 109 Strange Things                                         1.0
# 12th Annual Soompi Awards                                  0.0
# 2 Days and 1 Night                                         1.0
# 2014 Idol Star Athletics Champio...                        1.0
# 2015 Idol Star Athletics Champio...                        1.0
#
# title                                2 Days and 1 Night  \
# title
# 109 Strange Things                             0.991835
# 12th Annual Soompi Awards                      1.000000
# 2 Days and 1 Night                             0.000000
# 2014 Idol Star Athletics Champio...            1.000000
# 2015 Idol Star Athletics Champio...            1.000000
#
# title                                2014 Idol Star Athletics Champio...  \
# title
# 109 Strange Things                                                   1.0
# 12th Annual Soompi Awards                                            1.0
# 2 Days and 1 Night                                                   1.0
# 2014 Idol Star Athletics Champio...                                  0.0
# 2015 Idol Star Athletics Champio...                                  1.0
#
# title                                2015 Idol Star Athletics Champio...  \
# title
# 109 Strange Things                                                   1.0
# 12th Annual Soompi Awards                                            1.0
# 2 Days and 1 Night                                                   1.0
# 2014 Idol Star Athletics Champio...                                  1.0
# 2015 Idol Star Athletics Champio...                                  0.0
#
# title                                2016 DMC Festival  \
# title
# 109 Strange Things                                 1.0
# 12th Annual Soompi Awards                          1.0
# 2 Days and 1 Night                                 1.0
# 2014 Idol Star Athletics Champio...                1.0
# 2015 Idol Star Athletics Champio...                1.0
#
# title                                2016 Idol Star Athletics Champio...  \
# title
# 109 Strange Things                                              1.000000
# 12th Annual Soompi Awards                                       1.000000
# 2 Days and 1 Night                                              0.984146
# 2014 Idol Star Athletics Champio...                             1.000000
# 2015 Idol Star Athletics Champio...                             0.885266
#
# title                                2017 Idol Star Athletics Champio...  \
# title
# 109 Strange Things                                                   1.0
# 12th Annual Soompi Awards                                            1.0
# 2 Days and 1 Night                                                   1.0
# 2014 Idol Star Athletics Champio...                                  1.0
# 2015 Idol Star Athletics Champio...                                  1.0
#
# title                                2017 KBS Drama Awards  \
# title
# 109 Strange Things                                     1.0
# 12th Annual Soompi Awards                              1.0
# 2 Days and 1 Night                                     1.0
# 2014 Idol Star Athletics Champio...                    1.0
# 2015 Idol Star Athletics Champio...                    1.0
#
# title                                2017 KBS Song Festival    ...      \
# title                                                          ...
# 109 Strange Things                                      1.0    ...
# 12th Annual Soompi Awards                               1.0    ...
# 2 Days and 1 Night                                      1.0    ...
# 2014 Idol Star Athletics Champio...                     1.0    ...
# 2015 Idol Star Athletics Champio...                     1.0    ...
#
# title                                YoGoBaLa  You Are The Best  \
# title
# 109 Strange Things                        1.0          0.993757
# 12th Annual Soompi Awards                 1.0          1.000000
# 2 Days and 1 Night                        1.0          1.000000
# 2014 Idol Star Athletics Champio...       1.0          1.000000
# 2015 Idol Star Athletics Champio...       1.0          1.000000
#
# title                                You Are Too Much  You Drive Me Crazy  \
# title
# 109 Strange Things                                1.0            0.949538
# 12th Annual Soompi Awards                         1.0            1.000000
# 2 Days and 1 Night                                1.0            0.976157
# 2014 Idol Star Athletics Champio...               1.0            1.000000
# 2015 Idol Star Athletics Champio...               1.0            0.968942
#
# title                                Youn's Kitchen 2  Your Honor  \
# title
# 109 Strange Things                           1.000000    0.966719
# 12th Annual Soompi Awards                    1.000000    1.000000
# 2 Days and 1 Night                           0.974806    0.954312
# 2014 Idol Star Athletics Champio...          1.000000    1.000000
# 2015 Idol Star Athletics Champio...          1.000000    1.000000
#
# title                                Your House Helper  You’re Beautiful  \
# title
# 109 Strange Things                            0.979238          0.982405
# 12th Annual Soompi Awards                     1.000000          1.000000
# 2 Days and 1 Night                            0.986439          0.987525
# 2014 Idol Star Athletics Champio...           1.000000          1.000000
# 2015 Idol Star Athletics Champio...           1.000000          1.000000
#
# title                                Yu Huiyeol’s Sketchbook  to. Jenny
# title
# 109 Strange Things                                       1.0   0.967651
# 12th Annual Soompi Awards                                1.0   1.000000
# 2 Days and 1 Night                                       1.0   0.994297
# 2014 Idol Star Athletics Champio...                      1.0   1.000000
# 2015 Idol Star Athletics Champio...                      1.0   1.000000
#
# [5 rows x 618 columns]

# %% [markdown]
# ## Recommender Results

# %%
# system for titles with the given word and display top 10 matches
search = "Flowers"
for t in shows[shows['title'].str.contains(search)]['title'].values:
    print(t)
    print('Average Rating', data[data['title']==t]['rating'].mean())
    print('Number of Ratings', data[data['title']==t]['rating'].shape[0])
    print(' ')
    print('Recommendations:')
    print(recommender_df[t].sort_values()[1:11])
    print(' ')
    print('***********************************************************')
# Out:
# Boys Over Flowers
# Average Rating 9.40739289446186
# Number of Ratings 7656
#
# Recommendations:
# title
# Playful Kiss                  0.843600
# My Love From the Star         0.890176
# You’re Beautiful              0.891456
# Pinocchio                     0.895207
# The Legend of the Blue Sea    0.902742
# Strong Woman Do Bong Soon     0.907004
# Secret Garden                 0.907130
# Oh My Venus                   0.907468
# Coffee Prince                 0.908676
# Fated to Love You             0.912778
# Name: Boys Over Flowers, dtype: float64
#
# ***********************************************************
